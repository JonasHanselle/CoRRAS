# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from Corras.Scenario.aslib_ranking_scenario import ASRankingScenario
from itertools import product

# measures
from scipy.stats import kendalltau, describe
from sklearn.metrics import mean_absolute_error, mean_squared_error
from Corras.Evaluation.evaluation import ndcg_at_k, compute_relevance_scores_unit_interval

# plotting
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
scenario_path = "./aslib_data-aslib-v4.0/"
evaluations_path = "./evaluations/"

figures_path = "./figures/progression-plots/"
scenario_names = ["SAT11-RAND", "MIP-2016",
                  "CSP-2010", "SAT11-INDU", "SAT11-HAND"]
use_quadratic_transform_values = [True]
use_max_inverse_transform_values = ["max_cutoff", "max_par10"]
# scale_target_to_unit_interval_values = [True, False]
scale_target_to_unit_interval_values = [True]
seed = 15

params = [scenario_names, use_quadratic_transform_values,
          use_max_inverse_transform_values, scale_target_to_unit_interval_values]

param_product = list(product(*params))

# %%
for scenario_name, use_quadratic_transform, use_max_inverse_transform, scale_target_to_unit_interval in param_product:
    df_baseline_lr = None
    df_baseline_rf = None
    params_string = "-".join([scenario_name,
                              str(use_quadratic_transform), str(use_max_inverse_transform), str(scale_target_to_unit_interval)])
    try:
        df_baseline_lr = pd.read_csv(
            evaluations_path + "baseline-evaluation-linear-regression" + scenario_name + ".csv")
        df_baseline_rf = pd.read_csv(
            evaluations_path + "baseline-evaluation-random_forest" + scenario_name + ".csv")
    except:
        print("Scenario " + scenario_name +
              " not found in corras evaluation data!")

        # continue
    try:
        # df_corras = pd.read_csv(evaluations_path + "corras-linhinge-evaluation-" + scenario_name + ".csv")
        corras = pd.read_csv(
            evaluations_path + "corras-pl-log-linear-" + scenario_name + ".csv")
    except:
        print("Scenario " + scenario_name +
              " not found in corras evaluation data!")
        continue
    current_frame = corras.loc[(corras["seed"] == seed) & (
    corras["quadratic_transform"] == use_quadratic_transform) & (corras["scale_to_unit_interval"] == scale_target_to_unit_interval) & (corras["max_inverse_transform"] == "max_cutoff")]

    print(current_frame[:])
    for measure in current_frame.columns[8:]:
        plt.clf()
        # bp = sns.boxplot(x="lambda", y=measure, hue="epsilon", data=df_corras)
        # bp = sns.boxplot(x="lambda", y=measure, data=df_corras)
        # if df_baseline is not None:
        #     bp.axes.axhline(df_baseline[measure].mean(), c="g", ls="--", label="rf-baseline-mean")
        # plt.title(scenario_name)
        # plt.legend()
        # plt.savefig(figures_path+scenario_name+"-" + measure +"-boxplot.pdf")

    for measure in current_frame.columns[8:]:
        plt.clf()
        # bp = sns.lineplot(x="lambda", y=measure, hue="epsilon", data=df_corras, palette=sns.color_palette("Set1", len(pd.unique(df_corras["epsilon"]))))
        # g = sns.FacetGrid(df_corras, col="max_inverse_transform")
        # g.map(sns.lineplot, "lambda", measure)
        lp = sns.lineplot(x="lambda", y=measure, hue="max_inverse_transform", data=current_frame)
        if df_baseline_rf is not None:
            lp.axes.axhline(df_baseline_rf[measure].mean(
            ), c="g", ls="--", label="rf-baseline-mean")
        if df_baseline_lr is not None:    
            lp.axes.axhline(df_baseline_lr[measure].mean(
            ), c="m", ls="--", label="lr-baseline-mean")
        plt.title(scenario_name)
        plt.legend()
        plt.savefig(figures_path + scenario_name + "-" + params_string.replace(".","_") + "-" + measure + "-lineplot-mi.pdf")
        plt.show()
# Out:
#        Unnamed: 0  split  seed  \
# 120           120      1    15
# 121           121      1    15
# 122           122      1    15
# 123           123      1    15
# 124           124      1    15
# ...           ...    ...   ...
# 82135       82135     10    15
# 82136       82136     10    15
# 82137       82137     10    15
# 82138       82138     10    15
# 82139       82139     10    15
#
#                                         problem_instance  lambda  \
# 120    SAT11/random/large/unif-k3-r4.2-v10000-c42000-...     0.0
# 121    SAT11/random/large/unif-k3-r4.2-v20000-c84000-...     0.0
# 122    SAT11/random/large/unif-k3-r4.2-v20000-c84000-...     0.0
# 123    SAT11/random/large/unif-k3-r4.2-v20000-c84000-...     0.0
# 124    SAT11/random/large/unif-k3-r4.2-v2500-c10500-S...     0.0
# ...                                                  ...     ...
# 82135  SAT11/random/medium/unif-k7-r89-v70-c6230-S133...     1.0
# 82136  SAT11/random/medium/unif-k7-r89-v70-c6230-S204...     1.0
# 82137  SAT11/random/medium/unif-k7-r89-v70-c6230-S214...     1.0
# 82138  SAT11/random/medium/unif-k7-r89-v70-c6230-S250...     1.0
# 82139  SAT11/random/medium/unif-k7-r89-v90-c8010-S189...     1.0
#
#        quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 120                   True            max_cutoff                    True
# 121                   True            max_cutoff                    True
# 122                   True            max_cutoff                    True
# 123                   True            max_cutoff                    True
# 124                   True            max_cutoff                    True
# ...                    ...                   ...                     ...
# 82135                 True            max_cutoff                    True
# 82136                 True            max_cutoff                    True
# 82137                 True            max_cutoff                    True
# 82138                 True            max_cutoff                    True
# 82139                 True            max_cutoff                    True
#
#        tau_corr     tau_p      ndcg           mse           mae  \
# 120    0.478921  0.074735  0.989765  4.436538e+08  10289.228099
# 121    0.929670  0.000542  0.999876  4.473969e+08  11033.880690
# 122    0.547723  0.048632  0.953590  9.703894e+08  20859.160967
# 123    0.783349  0.004069  0.994618  6.506855e+08  15816.797147
# 124    0.704295  0.008775  0.998828  4.535974e+08  10733.713272
# ...         ...       ...       ...           ...           ...
# 82135 -0.444444  0.119439  0.980948  5.075438e+07   5600.449319
# 82136  0.333333  0.259518  0.999832  8.396472e+07   7620.013316
# 82137  0.000000  1.080545  0.937052  9.966037e+07   8230.610232
# 82138 -0.473365  0.111103  0.396435  1.888523e+09  38919.402242
# 82139       NaN       NaN       NaN  2.221849e+09  44887.468765
#
#        abs_distance_to_vbs        par10
# 120             256.756900    262.70100
# 121               0.000000      8.62369
# 122             105.883000    191.24600
# 123              48.556600     69.61740
# 124               0.000000      1.91271
# ...                    ...          ...
# 82135             8.946635      8.97663
# 82136             4.504314      5.05523
# 82137             3.590450      5.63814
# 82138         45601.440000  50000.00000
# 82139             0.000000  50000.00000
#
# [6840 rows x 15 columns]
#        Unnamed: 0  split  seed  \
# 120           120      1    15
# 121           121      1    15
# 122           122      1    15
# 123           123      1    15
# 124           124      1    15
# ...           ...    ...   ...
# 82135       82135     10    15
# 82136       82136     10    15
# 82137       82137     10    15
# 82138       82138     10    15
# 82139       82139     10    15
#
#                                         problem_instance  lambda  \
# 120    SAT11/random/large/unif-k3-r4.2-v10000-c42000-...     0.0
# 121    SAT11/random/large/unif-k3-r4.2-v20000-c84000-...     0.0
# 122    SAT11/random/large/unif-k3-r4.2-v20000-c84000-...     0.0
# 123    SAT11/random/large/unif-k3-r4.2-v20000-c84000-...     0.0
# 124    SAT11/random/large/unif-k3-r4.2-v2500-c10500-S...     0.0
# ...                                                  ...     ...
# 82135  SAT11/random/medium/unif-k7-r89-v70-c6230-S133...     1.0
# 82136  SAT11/random/medium/unif-k7-r89-v70-c6230-S204...     1.0
# 82137  SAT11/random/medium/unif-k7-r89-v70-c6230-S214...     1.0
# 82138  SAT11/random/medium/unif-k7-r89-v70-c6230-S250...     1.0
# 82139  SAT11/random/medium/unif-k7-r89-v90-c8010-S189...     1.0
#
#        quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 120                   True            max_cutoff                    True
# 121                   True            max_cutoff                    True
# 122                   True            max_cutoff                    True
# 123                   True            max_cutoff                    True
# 124                   True            max_cutoff                    True
# ...                    ...                   ...                     ...
# 82135                 True            max_cutoff                    True
# 82136                 True            max_cutoff                    True
# 82137                 True            max_cutoff                    True
# 82138                 True            max_cutoff                    True
# 82139                 True            max_cutoff                    True
#
#        tau_corr     tau_p      ndcg           mse           mae  \
# 120    0.478921  0.074735  0.989765  4.436538e+08  10289.228099
# 121    0.929670  0.000542  0.999876  4.473969e+08  11033.880690
# 122    0.547723  0.048632  0.953590  9.703894e+08  20859.160967
# 123    0.783349  0.004069  0.994618  6.506855e+08  15816.797147
# 124    0.704295  0.008775  0.998828  4.535974e+08  10733.713272
# ...         ...       ...       ...           ...           ...
# 82135 -0.444444  0.119439  0.980948  5.075438e+07   5600.449319
# 82136  0.333333  0.259518  0.999832  8.396472e+07   7620.013316
# 82137  0.000000  1.080545  0.937052  9.966037e+07   8230.610232
# 82138 -0.473365  0.111103  0.396435  1.888523e+09  38919.402242
# 82139       NaN       NaN       NaN  2.221849e+09  44887.468765
#
#        abs_distance_to_vbs        par10
# 120             256.756900    262.70100
# 121               0.000000      8.62369
# 122             105.883000    191.24600
# 123              48.556600     69.61740
# 124               0.000000      1.91271
# ...                    ...          ...
# 82135             8.946635      8.97663
# 82136             4.504314      5.05523
# 82137             3.590450      5.63814
# 82138         45601.440000  50000.00000
# 82139             0.000000  50000.00000
#
# [6840 rows x 15 columns]
#        Unnamed: 0  split  seed   problem_instance  lambda  \
# 44             44      1    15             a1c1s1     0.0
# 45             45      1    15              air04     0.0
# 46             46      1    15    ash608gpia-3col     0.0
# 47             47      1    15            danoint     0.0
# 48             48      1    15             glass4     0.0
# ...           ...    ...   ...                ...     ...
# 36430       36430     10    15            rail507     1.0
# 36431       36431     10    15             rmine6     1.0
# 36432       36432     10    15   rococoC11-011100     1.0
# 36433       36433     10    15  satellites2-60-fs     1.0
# 36434       36434     10    15           wachplan     1.0
#
#        quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 44                    True            max_cutoff                    True
# 45                    True            max_cutoff                    True
# 46                    True            max_cutoff                    True
# 47                    True            max_cutoff                    True
# 48                    True            max_cutoff                    True
# ...                    ...                   ...                     ...
# 36430                 True            max_cutoff                    True
# 36431                 True            max_cutoff                    True
# 36432                 True            max_cutoff                    True
# 36433                 True            max_cutoff                    True
# 36434                 True            max_cutoff                    True
#
#        tau_corr     tau_p      ndcg           mse           mae  \
# 44     0.737865  0.076974  0.981501  1.916291e+09  2.825453e+04
# 45     0.800000  0.083333  0.999983  5.092384e+06  1.729509e+03
# 46     0.800000  0.083333  0.999726  1.562903e+06  9.052887e+02
# 47     0.800000  0.083333  0.999119  3.205930e+06  1.410863e+03
# 48     0.105409  0.800542  0.903664  6.438479e+16  2.316921e+08
# ...         ...       ...       ...           ...           ...
# 36430  0.600000  0.233333  0.998898  5.773511e+08  1.891736e+04
# 36431  0.200000  0.816667  0.997120  1.320336e+08  7.019218e+03
# 36432 -0.200000  0.816667  0.700198  1.398369e+09  3.460683e+04
# 36433  0.105409  0.800542  0.886503  5.531612e+09  6.532626e+04
# 36434  0.200000  0.816667  0.989702  2.506395e+08  1.420688e+04
#
#        abs_distance_to_vbs   par10
# 44                     0.0   160.0
# 45                     1.0     5.0
# 46                     0.0     1.0
# 47                     0.0   128.0
# 48                    32.0    39.0
# ...                    ...     ...
# 36430                  0.0    26.0
# 36431                 30.0   106.0
# 36432               4532.0  6934.0
# 36433                 20.0   859.0
# 36434                268.0   434.0
#
# [3052 rows x 15 columns]
#        Unnamed: 0  split  seed   problem_instance  lambda  \
# 44             44      1    15             a1c1s1     0.0
# 45             45      1    15              air04     0.0
# 46             46      1    15    ash608gpia-3col     0.0
# 47             47      1    15            danoint     0.0
# 48             48      1    15             glass4     0.0
# ...           ...    ...   ...                ...     ...
# 36430       36430     10    15            rail507     1.0
# 36431       36431     10    15             rmine6     1.0
# 36432       36432     10    15   rococoC11-011100     1.0
# 36433       36433     10    15  satellites2-60-fs     1.0
# 36434       36434     10    15           wachplan     1.0
#
#        quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 44                    True            max_cutoff                    True
# 45                    True            max_cutoff                    True
# 46                    True            max_cutoff                    True
# 47                    True            max_cutoff                    True
# 48                    True            max_cutoff                    True
# ...                    ...                   ...                     ...
# 36430                 True            max_cutoff                    True
# 36431                 True            max_cutoff                    True
# 36432                 True            max_cutoff                    True
# 36433                 True            max_cutoff                    True
# 36434                 True            max_cutoff                    True
#
#        tau_corr     tau_p      ndcg           mse           mae  \
# 44     0.737865  0.076974  0.981501  1.916291e+09  2.825453e+04
# 45     0.800000  0.083333  0.999983  5.092384e+06  1.729509e+03
# 46     0.800000  0.083333  0.999726  1.562903e+06  9.052887e+02
# 47     0.800000  0.083333  0.999119  3.205930e+06  1.410863e+03
# 48     0.105409  0.800542  0.903664  6.438479e+16  2.316921e+08
# ...         ...       ...       ...           ...           ...
# 36430  0.600000  0.233333  0.998898  5.773511e+08  1.891736e+04
# 36431  0.200000  0.816667  0.997120  1.320336e+08  7.019218e+03
# 36432 -0.200000  0.816667  0.700198  1.398369e+09  3.460683e+04
# 36433  0.105409  0.800542  0.886503  5.531612e+09  6.532626e+04
# 36434  0.200000  0.816667  0.989702  2.506395e+08  1.420688e+04
#
#        abs_distance_to_vbs   par10
# 44                     0.0   160.0
# 45                     1.0     5.0
# 46                     0.0     1.0
# 47                     0.0   128.0
# 48                    32.0    39.0
# ...                    ...     ...
# 36430                  0.0    26.0
# 36431                 30.0   106.0
# 36432               4532.0  6934.0
# 36433                 20.0   859.0
# 36434                268.0   434.0
#
# [3052 rows x 15 columns]
#         Unnamed: 0  split  seed                              problem_instance  \
# 406            406      1    15         1-fullins-4-5.xml.watchless.minion.gz
# 407            407      1    15      1-insertions-6-4.xml.watchless.minion.gz
# 408            408      1    15      1-insertions-6-6.xml.watchless.minion.gz
# 409            409      1    15         2-fullins-3-5.xml.watchless.minion.gz
# 410            410      1    15      2-insertions-4-3.xml.watchless.minion.gz
# ...            ...    ...   ...                                           ...
# 338200      338200     10    15              series-90.xml.minion.conv.minion
# 338201      338201     10    15                 socialGolfer-8-4-8.xml.minion
# 338202      338202     10    15  tsp-20-68_ext.xml.minion.converted.minion.gz
# 338203      338203     10    15  tsp-20-75_ext.xml.minion.converted.minion.gz
# 338204      338204     10    15         will199GPIA-7.xml.watchless.minion.gz
#
#         lambda  quadratic_transform max_inverse_transform  \
# 406        0.0                 True            max_cutoff
# 407        0.0                 True            max_cutoff
# 408        0.0                 True            max_cutoff
# 409        0.0                 True            max_cutoff
# 410        0.0                 True            max_cutoff
# ...        ...                  ...                   ...
# 338200     1.0                 True            max_cutoff
# 338201     1.0                 True            max_cutoff
# 338202     1.0                 True            max_cutoff
# 338203     1.0                 True            max_cutoff
# 338204     1.0                 True            max_cutoff
#
#         scale_to_unit_interval  tau_corr  tau_p  ndcg           mse  \
# 406                       True       1.0    1.0   1.0  3.635689e+05
# 407                       True       NaN    NaN   NaN  2.502640e+09
# 408                       True       NaN    NaN   NaN  2.461583e+09
# 409                       True       1.0    1.0   1.0  6.206658e+04
# 410                       True       1.0    1.0   1.0  4.517024e+05
# ...                        ...       ...    ...   ...           ...
# 338200                    True       NaN    NaN   NaN  2.420319e+09
# 338201                    True       NaN    NaN   NaN  5.921381e+11
# 338202                    True       1.0    1.0   1.0  8.187236e+08
# 338203                    True       1.0    1.0   1.0  9.458905e+08
# 338204                    True       1.0    1.0   1.0  1.215440e+09
#
#                   mae  abs_distance_to_vbs         par10
# 406        459.378972                  0.0      0.171973
# 407      50025.887781                  0.0  50000.000000
# 408      49613.437878                  0.0  50000.000000
# 409        216.002617                  0.0      0.162975
# 410        665.172496                  0.0      0.099985
# ...               ...                  ...           ...
# 338200   45557.610865                  0.0  50000.000000
# 338201  768121.258109                  0.0  50000.000000
# 338202   28186.162044                  0.0      0.638902
# 338203   30453.175683                  0.0      3.765428
# 338204   34449.221032                  0.0      0.276958
#
# [28336 rows x 15 columns]
#         Unnamed: 0  split  seed                              problem_instance  \
# 406            406      1    15         1-fullins-4-5.xml.watchless.minion.gz
# 407            407      1    15      1-insertions-6-4.xml.watchless.minion.gz
# 408            408      1    15      1-insertions-6-6.xml.watchless.minion.gz
# 409            409      1    15         2-fullins-3-5.xml.watchless.minion.gz
# 410            410      1    15      2-insertions-4-3.xml.watchless.minion.gz
# ...            ...    ...   ...                                           ...
# 338200      338200     10    15              series-90.xml.minion.conv.minion
# 338201      338201     10    15                 socialGolfer-8-4-8.xml.minion
# 338202      338202     10    15  tsp-20-68_ext.xml.minion.converted.minion.gz
# 338203      338203     10    15  tsp-20-75_ext.xml.minion.converted.minion.gz
# 338204      338204     10    15         will199GPIA-7.xml.watchless.minion.gz
#
#         lambda  quadratic_transform max_inverse_transform  \
# 406        0.0                 True            max_cutoff
# 407        0.0                 True            max_cutoff
# 408        0.0                 True            max_cutoff
# 409        0.0                 True            max_cutoff
# 410        0.0                 True            max_cutoff
# ...        ...                  ...                   ...
# 338200     1.0                 True            max_cutoff
# 338201     1.0                 True            max_cutoff
# 338202     1.0                 True            max_cutoff
# 338203     1.0                 True            max_cutoff
# 338204     1.0                 True            max_cutoff
#
#         scale_to_unit_interval  tau_corr  tau_p  ndcg           mse  \
# 406                       True       1.0    1.0   1.0  3.635689e+05
# 407                       True       NaN    NaN   NaN  2.502640e+09
# 408                       True       NaN    NaN   NaN  2.461583e+09
# 409                       True       1.0    1.0   1.0  6.206658e+04
# 410                       True       1.0    1.0   1.0  4.517024e+05
# ...                        ...       ...    ...   ...           ...
# 338200                    True       NaN    NaN   NaN  2.420319e+09
# 338201                    True       NaN    NaN   NaN  5.921381e+11
# 338202                    True       1.0    1.0   1.0  8.187236e+08
# 338203                    True       1.0    1.0   1.0  9.458905e+08
# 338204                    True       1.0    1.0   1.0  1.215440e+09
#
#                   mae  abs_distance_to_vbs         par10
# 406        459.378972                  0.0      0.171973
# 407      50025.887781                  0.0  50000.000000
# 408      49613.437878                  0.0  50000.000000
# 409        216.002617                  0.0      0.162975
# 410        665.172496                  0.0      0.099985
# ...               ...                  ...           ...
# 338200   45557.610865                  0.0  50000.000000
# 338201  768121.258109                  0.0  50000.000000
# 338202   28186.162044                  0.0      0.638902
# 338203   30453.175683                  0.0      3.765428
# 338204   34449.221032                  0.0      0.276958
#
# [28336 rows x 15 columns]
#        Unnamed: 0  split  seed  \
# 300           300      2    15
# 301           301      2    15
# 302           302      2    15
# 303           303      2    15
# 304           304      2    15
# ...           ...    ...   ...
# 18978       18978      4    15
# 18979       18979      4    15
# 18980       18980      4    15
# 18981       18981      4    15
# 18982       18982      4    15
#
#                                         problem_instance  lambda  \
# 300    ./SAT02/industrial/goldberg/fpga_routing/vda_g...    0.01
# 301    ./SAT03/industrial/li/li-exam/li-exam-61.shuff...    0.01
# 302    ./SAT07/industrial/anbulagan/medium-unsat/date...    0.01
# 303    ./SAT07/industrial/babic/dspam/dspam_dump_vc94...    0.01
# 304    ./SAT09/APPLICATIONS/bitverif/minandmaxor/mina...    0.01
# ...                                                  ...     ...
# 18978  ./SAT11/application/rintanen/SATPlanning/trans...    1.00
# 18979  ./SAT11/application/rintanen/SATPlanning/trans...    1.00
# 18980  ./SAT11/application/rintanen/SATPlanning/trans...    1.00
# 18981  SAT-Race-2010-CNF/software-verification/nec/ha...    1.00
# 18982                   SAT_RACE08/Q1/SAT_dat.k80_04.cnf    1.00
#
#        quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 300                   True            max_cutoff                    True
# 301                   True            max_cutoff                    True
# 302                   True            max_cutoff                    True
# 303                   True            max_cutoff                    True
# 304                   True            max_cutoff                    True
# ...                    ...                   ...                     ...
# 18978                 True            max_cutoff                    True
# 18979                 True            max_cutoff                    True
# 18980                 True            max_cutoff                    True
# 18981                 True            max_cutoff                    True
# 18982                 True            max_cutoff                    True
#
#        tau_corr     tau_p      ndcg           mse            mae  \
# 300   -0.354100  0.040671  0.999953  2.932857e+07    5054.452232
# 301         NaN       NaN       NaN  1.649031e+09   40596.265584
# 302    0.189542  0.293451  0.999221  5.901812e+06    2253.506356
# 303   -0.104919  0.544197  0.999926  1.219697e+08    2988.504004
# 304   -0.081666  0.664612  0.792339  1.295276e+09   28673.810062
# ...         ...       ...       ...           ...            ...
# 18978  0.304228  0.084483  0.826989  1.100538e+10   85835.155042
# 18979  0.276543  0.132513  0.865564  1.310990e+11  288841.810654
# 18980  0.323687  0.107040  0.627220  7.980049e+09   72104.594061
# 18981  0.254902  0.151923  0.999861  2.106828e+09   39169.909082
# 18982  0.215686  0.229060  0.999059  6.628230e+09   62350.407672
#
#        abs_distance_to_vbs         par10
# 300               1.122830      1.379790
# 301               0.000000  50000.000000
# 302              19.861900     35.915500
# 303               0.080988      0.528919
# 304             277.080000   2248.950000
# ...                    ...           ...
# 18978         49870.335000  50000.000000
# 18979             0.000000    363.759000
# 18980           812.290000   4339.420000
# 18981             0.405940      4.409330
# 18982             4.372400     15.441700
#
# [1590 rows x 15 columns]
#        Unnamed: 0  split  seed  \
# 300           300      2    15
# 301           301      2    15
# 302           302      2    15
# 303           303      2    15
# 304           304      2    15
# ...           ...    ...   ...
# 18978       18978      4    15
# 18979       18979      4    15
# 18980       18980      4    15
# 18981       18981      4    15
# 18982       18982      4    15
#
#                                         problem_instance  lambda  \
# 300    ./SAT02/industrial/goldberg/fpga_routing/vda_g...    0.01
# 301    ./SAT03/industrial/li/li-exam/li-exam-61.shuff...    0.01
# 302    ./SAT07/industrial/anbulagan/medium-unsat/date...    0.01
# 303    ./SAT07/industrial/babic/dspam/dspam_dump_vc94...    0.01
# 304    ./SAT09/APPLICATIONS/bitverif/minandmaxor/mina...    0.01
# ...                                                  ...     ...
# 18978  ./SAT11/application/rintanen/SATPlanning/trans...    1.00
# 18979  ./SAT11/application/rintanen/SATPlanning/trans...    1.00
# 18980  ./SAT11/application/rintanen/SATPlanning/trans...    1.00
# 18981  SAT-Race-2010-CNF/software-verification/nec/ha...    1.00
# 18982                   SAT_RACE08/Q1/SAT_dat.k80_04.cnf    1.00
#
#        quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 300                   True            max_cutoff                    True
# 301                   True            max_cutoff                    True
# 302                   True            max_cutoff                    True
# 303                   True            max_cutoff                    True
# 304                   True            max_cutoff                    True
# ...                    ...                   ...                     ...
# 18978                 True            max_cutoff                    True
# 18979                 True            max_cutoff                    True
# 18980                 True            max_cutoff                    True
# 18981                 True            max_cutoff                    True
# 18982                 True            max_cutoff                    True
#
#        tau_corr     tau_p      ndcg           mse            mae  \
# 300   -0.354100  0.040671  0.999953  2.932857e+07    5054.452232
# 301         NaN       NaN       NaN  1.649031e+09   40596.265584
# 302    0.189542  0.293451  0.999221  5.901812e+06    2253.506356
# 303   -0.104919  0.544197  0.999926  1.219697e+08    2988.504004
# 304   -0.081666  0.664612  0.792339  1.295276e+09   28673.810062
# ...         ...       ...       ...           ...            ...
# 18978  0.304228  0.084483  0.826989  1.100538e+10   85835.155042
# 18979  0.276543  0.132513  0.865564  1.310990e+11  288841.810654
# 18980  0.323687  0.107040  0.627220  7.980049e+09   72104.594061
# 18981  0.254902  0.151923  0.999861  2.106828e+09   39169.909082
# 18982  0.215686  0.229060  0.999059  6.628230e+09   62350.407672
#
#        abs_distance_to_vbs         par10
# 300               1.122830      1.379790
# 301               0.000000  50000.000000
# 302              19.861900     35.915500
# 303               0.080988      0.528919
# 304             277.080000   2248.950000
# ...                    ...           ...
# 18978         49870.335000  50000.000000
# 18979             0.000000    363.759000
# 18980           812.290000   4339.420000
# 18981             0.405940      4.409330
# 18982             4.372400     15.441700
#
# [1590 rows x 15 columns]
#        Unnamed: 0  split  seed  \
# 60             60      1    15
# 61             61      1    15
# 62             62      1    15
# 63             63      1    15
# 64             64      1    15
# ...           ...    ...   ...
# 49462       49462     10    15
# 49463       49463     10    15
# 49464       49464     10    15
# 49465       49465     10    15
# 49466       49466     10    15
#
#                                         problem_instance  lambda  \
# 60     ./SAT03/handmade/anton/UNSAT/SGI_30_60_28_40_7...     0.0
# 61     ./SAT03/handmade/stanion/hwb/hwb-n32-02-S14785...     0.0
# 62     ./SAT05/crafted/jarvisalo05/mod2-rand3bip-sat/...     0.0
# 63     ./SAT05/crafted/jarvisalo05/mod2c-rand3bip-sat...     0.0
# 64     ./SAT05/crafted/sabharwal05/planning/logistics...     0.0
# ...                                                  ...     ...
# 49462      ./SAT11/crafted/mosoi/289/289-unsat-14x38.cnf     1.0
# 49463  ./SAT11/crafted/skvortsov/battleship/battleshi...     1.0
# 49464  ./SAT11/crafted/skvortsov/battleship/battleshi...     1.0
# 49465  ./SAT11/crafted/spence/sgen/sgen3-n130-s309409...     1.0
# 49466  ./SAT11/crafted/spence/sgen/sgen3-n260-s623210...     1.0
#
#        quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 60                    True            max_cutoff                    True
# 61                    True            max_cutoff                    True
# 62                    True            max_cutoff                    True
# 63                    True            max_cutoff                    True
# 64                    True            max_cutoff                    True
# ...                    ...                   ...                     ...
# 49462                 True            max_cutoff                    True
# 49463                 True            max_cutoff                    True
# 49464                 True            max_cutoff                    True
# 49465                 True            max_cutoff                    True
# 49466                 True            max_cutoff                    True
#
#        tau_corr     tau_p      ndcg           mse            mae  \
# 60     0.156492  0.487453  0.386853  1.969681e+09   42873.754551
# 61          NaN       NaN       NaN  2.101489e+09   45831.494540
# 62    -0.078135  0.720757  0.767055  1.595557e+09   36452.124868
# 63     0.669662  0.001352  0.940373  1.238876e+09   27599.478430
# 64     0.229668  0.234381  0.988297  3.166949e+08    8624.313594
# ...         ...       ...       ...           ...            ...
# 49462       NaN       NaN       NaN  5.103886e+10  201019.064447
# 49463  0.328537  0.090996  0.936410  7.728153e+10  236684.176933
# 49464       NaN       NaN       NaN  3.939743e+10  158538.710718
# 49465       NaN       NaN       NaN  9.006716e+10  254658.270607
# 49466  0.578196  0.008167  0.996188  1.676979e+11  328562.149080
#
#        abs_distance_to_vbs         par10
# 60            45953.000000  50000.000000
# 61                0.000000  50000.000000
# 62                0.000000      0.005998
# 63              720.689000    855.848000
# 64                4.162369      4.681290
# ...                    ...           ...
# 49462             0.000000  50000.000000
# 49463             7.858800     32.129100
# 49464             0.000000  50000.000000
# 49465             0.000000  50000.000000
# 49466           107.950600    125.005000
#
# [4144 rows x 15 columns]
#        Unnamed: 0  split  seed  \
# 60             60      1    15
# 61             61      1    15
# 62             62      1    15
# 63             63      1    15
# 64             64      1    15
# ...           ...    ...   ...
# 49462       49462     10    15
# 49463       49463     10    15
# 49464       49464     10    15
# 49465       49465     10    15
# 49466       49466     10    15
#
#                                         problem_instance  lambda  \
# 60     ./SAT03/handmade/anton/UNSAT/SGI_30_60_28_40_7...     0.0
# 61     ./SAT03/handmade/stanion/hwb/hwb-n32-02-S14785...     0.0
# 62     ./SAT05/crafted/jarvisalo05/mod2-rand3bip-sat/...     0.0
# 63     ./SAT05/crafted/jarvisalo05/mod2c-rand3bip-sat...     0.0
# 64     ./SAT05/crafted/sabharwal05/planning/logistics...     0.0
# ...                                                  ...     ...
# 49462      ./SAT11/crafted/mosoi/289/289-unsat-14x38.cnf     1.0
# 49463  ./SAT11/crafted/skvortsov/battleship/battleshi...     1.0
# 49464  ./SAT11/crafted/skvortsov/battleship/battleshi...     1.0
# 49465  ./SAT11/crafted/spence/sgen/sgen3-n130-s309409...     1.0
# 49466  ./SAT11/crafted/spence/sgen/sgen3-n260-s623210...     1.0
#
#        quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 60                    True            max_cutoff                    True
# 61                    True            max_cutoff                    True
# 62                    True            max_cutoff                    True
# 63                    True            max_cutoff                    True
# 64                    True            max_cutoff                    True
# ...                    ...                   ...                     ...
# 49462                 True            max_cutoff                    True
# 49463                 True            max_cutoff                    True
# 49464                 True            max_cutoff                    True
# 49465                 True            max_cutoff                    True
# 49466                 True            max_cutoff                    True
#
#        tau_corr     tau_p      ndcg           mse            mae  \
# 60     0.156492  0.487453  0.386853  1.969681e+09   42873.754551
# 61          NaN       NaN       NaN  2.101489e+09   45831.494540
# 62    -0.078135  0.720757  0.767055  1.595557e+09   36452.124868
# 63     0.669662  0.001352  0.940373  1.238876e+09   27599.478430
# 64     0.229668  0.234381  0.988297  3.166949e+08    8624.313594
# ...         ...       ...       ...           ...            ...
# 49462       NaN       NaN       NaN  5.103886e+10  201019.064447
# 49463  0.328537  0.090996  0.936410  7.728153e+10  236684.176933
# 49464       NaN       NaN       NaN  3.939743e+10  158538.710718
# 49465       NaN       NaN       NaN  9.006716e+10  254658.270607
# 49466  0.578196  0.008167  0.996188  1.676979e+11  328562.149080
#
#        abs_distance_to_vbs         par10
# 60            45953.000000  50000.000000
# 61                0.000000  50000.000000
# 62                0.000000      0.005998
# 63              720.689000    855.848000
# 64                4.162369      4.681290
# ...                    ...           ...
# 49462             0.000000  50000.000000
# 49463             7.858800     32.129100
# 49464             0.000000  50000.000000
# 49465             0.000000  50000.000000
# 49466           107.950600    125.005000
#
# [4144 rows x 15 columns]

# %%
corras.head()
# Out:
#    Unnamed: 0  split  seed                                   problem_instance  \
# 0           0      1    15  ./SAT03/handmade/anton/UNSAT/SGI_30_60_28_40_7...
# 1           1      1    15  ./SAT03/handmade/stanion/hwb/hwb-n32-02-S14785...
# 2           2      1    15  ./SAT05/crafted/jarvisalo05/mod2-rand3bip-sat/...
# 3           3      1    15  ./SAT05/crafted/jarvisalo05/mod2c-rand3bip-sat...
# 4           4      1    15  ./SAT05/crafted/sabharwal05/planning/logistics...
#
#    lambda  quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 0     0.0                 True                  none                    True
# 1     0.0                 True                  none                    True
# 2     0.0                 True                  none                    True
# 3     0.0                 True                  none                    True
# 4     0.0                 True                  none                    True
#
#    tau_corr     tau_p      ndcg           mse           mae  \
# 0  0.104328  0.643429  0.356207  8.451010e+08  21090.251244
# 1       NaN       NaN       NaN  5.837298e+08  17550.495350
# 2 -0.046881  0.830182  0.766686  1.396414e+09  34731.419404
# 3  0.646165  0.001986  0.908346  1.314080e+08   5777.281178
# 4  0.172251  0.372467  0.987682  1.961951e+09  37073.542130
#
#    abs_distance_to_vbs         par10
# 0         45953.000000  50000.000000
# 1             0.000000  50000.000000
# 2             0.000000      0.005998
# 3          1733.261000   1868.420000
# 4             4.162369      4.681290
