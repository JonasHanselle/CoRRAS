# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from Corras.Scenario.aslib_ranking_scenario import ASRankingScenario
from itertools import product

# measures
from scipy.stats import kendalltau, describe
from sklearn.metrics import mean_absolute_error, mean_squared_error
from Corras.Evaluation.evaluation import ndcg_at_k, compute_relevance_scores_unit_interval

# plotting
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
scenario_path = "./aslib_data-aslib-v4.0/"
evaluations_path = "./evaluations/"

figures_path = "./figures/progression-plots/"
scenario_names = ["SAT11-RAND", "MIP-2016",
                  "CSP-2010", "SAT11-INDU", "SAT11-HAND"]
use_quadratic_transform_values = [True, False]
# use_max_inverse_transform_values = ["none", "max_cutoff", "max_par10"]
# scale_target_to_unit_interval_values = [True, False]
use_max_inverse_transform_values = ["none"]
scale_target_to_unit_interval_values = [True]

params = [scenario_names, use_quadratic_transform_values,
          use_max_inverse_transform_values, scale_target_to_unit_interval_values]

param_product = list(product(*params))

# %%
for scenario_name, use_quadratic_transform, use_max_inverse_transform, scale_target_to_unit_interval in param_product:
    df_baseline = None
    params_string = "-".join([scenario_name,
                              str(use_quadratic_transform), str(use_max_inverse_transform), str(scale_target_to_unit_interval)])
    try:
        df_baseline = pd.read_csv(
            evaluations_path + "baseline-evaluation-" + scenario_name + ".csv")
    except:
        print("Scenario " + scenario_name +
              " not found in corras evaluation data!")
        # continue
    try:
        # df_corras = pd.read_csv(evaluations_path + "corras-linhinge-evaluation-" + scenario_name + ".csv")
        df_corras = pd.read_csv(
            evaluations_path + "corras-pl-log-linear-" + scenario_name + ".csv")
    except:
        print("Scenario " + scenario_name +
              " not found in corras evaluation data!")
        continue
    # plot average kendall tau
    print(df_corras[:])
    for measure in df_corras.columns[8:]:
        plt.clf()
        # bp = sns.boxplot(x="lambda", y=measure, hue="epsilon", data=df_corras)
        # bp = sns.boxplot(x="lambda", y=measure, data=df_corras)
        # if df_baseline is not None:
        #     bp.axes.axhline(df_baseline[measure].mean(), c="g", ls="--", label="rf-baseline-mean")
        # plt.title(scenario_name)
        # plt.legend()
        # plt.savefig(figures_path+scenario_name+"-" + measure +"-boxplot.pdf")

    for measure in df_corras.columns[8:]:
        plt.clf()
        # bp = sns.lineplot(x="lambda", y=measure, hue="epsilon", data=df_corras, palette=sns.color_palette("Set1", len(pd.unique(df_corras["epsilon"]))))
        # g = sns.FacetGrid(df_corras, col="max_inverse_transform")
        # g.map(sns.lineplot, "lambda", measure)
        lp = sns.lineplot(x="lambda", y=measure, hue="quadratic_transform", data=df_corras)
        if df_baseline is not None:
            lp.axes.axhline(df_baseline[measure].mean(
            ), c="g", ls="--", label="rf-baseline-mean")
        plt.title(scenario_name)
        plt.legend()
        plt.savefig(figures_path + scenario_name + "-" + params_string + "-" + measure + "-lineplot.pdf")
        plt.show()
# Out:
#        Unnamed: 0  split  seed  \
# 0               0      1    15
# 1               1      1    15
# 2               2      1    15
# 3               3      1    15
# 4               4      1    15
# ...           ...    ...   ...
# 82675       82675     10    15
# 82676       82676     10    15
# 82677       82677     10    15
# 82678       82678     10    15
# 82679       82679     10    15
#
#                                         problem_instance  lambda  \
# 0      SAT11/random/large/unif-k3-r4.2-v10000-c42000-...     0.0
# 1      SAT11/random/large/unif-k3-r4.2-v20000-c84000-...     0.0
# 2      SAT11/random/large/unif-k3-r4.2-v20000-c84000-...     0.0
# 3      SAT11/random/large/unif-k3-r4.2-v20000-c84000-...     0.0
# 4      SAT11/random/large/unif-k3-r4.2-v2500-c10500-S...     0.0
# ...                                                  ...     ...
# 82675  SAT11/random/medium/unif-k7-r89-v70-c6230-S133...     1.0
# 82676  SAT11/random/medium/unif-k7-r89-v70-c6230-S204...     1.0
# 82677  SAT11/random/medium/unif-k7-r89-v70-c6230-S214...     1.0
# 82678  SAT11/random/medium/unif-k7-r89-v70-c6230-S250...     1.0
# 82679  SAT11/random/medium/unif-k7-r89-v90-c8010-S189...     1.0
#
#        quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 0                     True                  none                    True
# 1                     True                  none                    True
# 2                     True                  none                    True
# 3                     True                  none                    True
# 4                     True                  none                    True
# ...                    ...                   ...                     ...
# 82675                False             max_par10                   False
# 82676                False             max_par10                   False
# 82677                False             max_par10                   False
# 82678                False             max_par10                   False
# 82679                False             max_par10                   False
#
#        tau_corr     tau_p      ndcg           mse           mae  \
# 0      0.309890  0.248864  0.980682  5.513030e+07   6038.717199
# 1      0.929670  0.000542  0.999082  2.292490e+08  11969.471042
# 2      0.608581  0.028460  0.977323  4.839982e+08  16826.908896
# 3      0.725324  0.007815  0.993377  1.254010e+08   8364.841489
# 4      0.591608  0.027708  0.998310  1.326484e+08  10188.788909
# ...         ...       ...       ...           ...           ...
# 82675 -0.166667  0.612202  0.989837  2.482164e+09  49820.351125
# 82676  0.277778  0.358488  0.993326  2.432944e+09  49308.040298
# 82677  0.166667  0.612202  0.960298  2.407165e+09  49029.564867
# 82678 -0.043033  0.884836  0.575862  4.619524e+08  10132.962148
# 82679       NaN       NaN       NaN  1.458977e+00      0.986336
#
#        abs_distance_to_vbs        par10
# 0               256.756900    262.70100
# 1                 0.000000      8.62369
# 2               105.883000    191.24600
# 3                48.556600     69.61740
# 4                 0.000000      1.91271
# ...                    ...          ...
# 82675             8.946635      8.97663
# 82676             4.504314      5.05523
# 82677             3.590450      5.63814
# 82678         45601.440000  50000.00000
# 82679             0.000000  50000.00000
#
# [82680 rows x 15 columns]
#        Unnamed: 0  split  seed  \
# 0               0      1    15
# 1               1      1    15
# 2               2      1    15
# 3               3      1    15
# 4               4      1    15
# ...           ...    ...   ...
# 82675       82675     10    15
# 82676       82676     10    15
# 82677       82677     10    15
# 82678       82678     10    15
# 82679       82679     10    15
#
#                                         problem_instance  lambda  \
# 0      SAT11/random/large/unif-k3-r4.2-v10000-c42000-...     0.0
# 1      SAT11/random/large/unif-k3-r4.2-v20000-c84000-...     0.0
# 2      SAT11/random/large/unif-k3-r4.2-v20000-c84000-...     0.0
# 3      SAT11/random/large/unif-k3-r4.2-v20000-c84000-...     0.0
# 4      SAT11/random/large/unif-k3-r4.2-v2500-c10500-S...     0.0
# ...                                                  ...     ...
# 82675  SAT11/random/medium/unif-k7-r89-v70-c6230-S133...     1.0
# 82676  SAT11/random/medium/unif-k7-r89-v70-c6230-S204...     1.0
# 82677  SAT11/random/medium/unif-k7-r89-v70-c6230-S214...     1.0
# 82678  SAT11/random/medium/unif-k7-r89-v70-c6230-S250...     1.0
# 82679  SAT11/random/medium/unif-k7-r89-v90-c8010-S189...     1.0
#
#        quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 0                     True                  none                    True
# 1                     True                  none                    True
# 2                     True                  none                    True
# 3                     True                  none                    True
# 4                     True                  none                    True
# ...                    ...                   ...                     ...
# 82675                False             max_par10                   False
# 82676                False             max_par10                   False
# 82677                False             max_par10                   False
# 82678                False             max_par10                   False
# 82679                False             max_par10                   False
#
#        tau_corr     tau_p      ndcg           mse           mae  \
# 0      0.309890  0.248864  0.980682  5.513030e+07   6038.717199
# 1      0.929670  0.000542  0.999082  2.292490e+08  11969.471042
# 2      0.608581  0.028460  0.977323  4.839982e+08  16826.908896
# 3      0.725324  0.007815  0.993377  1.254010e+08   8364.841489
# 4      0.591608  0.027708  0.998310  1.326484e+08  10188.788909
# ...         ...       ...       ...           ...           ...
# 82675 -0.166667  0.612202  0.989837  2.482164e+09  49820.351125
# 82676  0.277778  0.358488  0.993326  2.432944e+09  49308.040298
# 82677  0.166667  0.612202  0.960298  2.407165e+09  49029.564867
# 82678 -0.043033  0.884836  0.575862  4.619524e+08  10132.962148
# 82679       NaN       NaN       NaN  1.458977e+00      0.986336
#
#        abs_distance_to_vbs        par10
# 0               256.756900    262.70100
# 1                 0.000000      8.62369
# 2               105.883000    191.24600
# 3                48.556600     69.61740
# 4                 0.000000      1.91271
# ...                    ...          ...
# 82675             8.946635      8.97663
# 82676             4.504314      5.05523
# 82677             3.590450      5.63814
# 82678         45601.440000  50000.00000
# 82679             0.000000  50000.00000
#
# [82680 rows x 15 columns]
#        Unnamed: 0  split  seed   problem_instance  lambda  \
# 0               0      1    15             a1c1s1     0.0
# 1               1      1    15              air04     0.0
# 2               2      1    15    ash608gpia-3col     0.0
# 3               3      1    15            danoint     0.0
# 4               4      1    15             glass4     0.0
# ...           ...    ...   ...                ...     ...
# 36619       36619     10    15            rail507     1.0
# 36620       36620     10    15             rmine6     1.0
# 36621       36621     10    15   rococoC11-011100     1.0
# 36622       36622     10    15  satellites2-60-fs     1.0
# 36623       36623     10    15           wachplan     1.0
#
#        quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 0                     True                  none                    True
# 1                     True                  none                    True
# 2                     True                  none                    True
# 3                     True                  none                    True
# 4                     True                  none                    True
# ...                    ...                   ...                     ...
# 36619                False             max_par10                   False
# 36620                False             max_par10                   False
# 36621                False             max_par10                   False
# 36622                False             max_par10                   False
# 36623                False             max_par10                   False
#
#        tau_corr     tau_p      ndcg           mse           mae  \
# 0      0.737865  0.076974  0.981501  9.187033e+08  2.414203e+04
# 1      0.600000  0.233333  0.999939  5.173136e+08  1.643862e+04
# 2      0.600000  0.233333  0.998936  1.919479e+08  9.954189e+03
# 3      0.800000  0.083333  0.999119  4.729381e+08  1.645303e+04
# 4      0.105409  0.800542  0.903664  7.368204e+18  2.437231e+09
# ...         ...       ...       ...           ...           ...
# 36619  0.600000  0.233333  0.999228  5.168120e+09  7.188959e+04
# 36620  0.200000  0.816667  0.997120  5.141025e+09  7.170061e+04
# 36621  0.200000  0.816667  0.877018  3.698032e+09  5.437619e+04
# 36622  0.737865  0.076974  0.999447  3.025515e+09  4.261120e+04
# 36623  0.000000  1.183333  0.981740  5.063571e+09  7.115421e+04
#
#        abs_distance_to_vbs   par10
# 0                      0.0   160.0
# 1                      1.0     5.0
# 2                     45.0    46.0
# 3                      0.0   128.0
# 4                     32.0    39.0
# ...                    ...     ...
# 36619                 22.0    48.0
# 36620                 30.0   106.0
# 36621               1661.0  4063.0
# 36622                 20.0   859.0
# 36623                268.0   434.0
#
# [36624 rows x 15 columns]
#        Unnamed: 0  split  seed   problem_instance  lambda  \
# 0               0      1    15             a1c1s1     0.0
# 1               1      1    15              air04     0.0
# 2               2      1    15    ash608gpia-3col     0.0
# 3               3      1    15            danoint     0.0
# 4               4      1    15             glass4     0.0
# ...           ...    ...   ...                ...     ...
# 36619       36619     10    15            rail507     1.0
# 36620       36620     10    15             rmine6     1.0
# 36621       36621     10    15   rococoC11-011100     1.0
# 36622       36622     10    15  satellites2-60-fs     1.0
# 36623       36623     10    15           wachplan     1.0
#
#        quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 0                     True                  none                    True
# 1                     True                  none                    True
# 2                     True                  none                    True
# 3                     True                  none                    True
# 4                     True                  none                    True
# ...                    ...                   ...                     ...
# 36619                False             max_par10                   False
# 36620                False             max_par10                   False
# 36621                False             max_par10                   False
# 36622                False             max_par10                   False
# 36623                False             max_par10                   False
#
#        tau_corr     tau_p      ndcg           mse           mae  \
# 0      0.737865  0.076974  0.981501  9.187033e+08  2.414203e+04
# 1      0.600000  0.233333  0.999939  5.173136e+08  1.643862e+04
# 2      0.600000  0.233333  0.998936  1.919479e+08  9.954189e+03
# 3      0.800000  0.083333  0.999119  4.729381e+08  1.645303e+04
# 4      0.105409  0.800542  0.903664  7.368204e+18  2.437231e+09
# ...         ...       ...       ...           ...           ...
# 36619  0.600000  0.233333  0.999228  5.168120e+09  7.188959e+04
# 36620  0.200000  0.816667  0.997120  5.141025e+09  7.170061e+04
# 36621  0.200000  0.816667  0.877018  3.698032e+09  5.437619e+04
# 36622  0.737865  0.076974  0.999447  3.025515e+09  4.261120e+04
# 36623  0.000000  1.183333  0.981740  5.063571e+09  7.115421e+04
#
#        abs_distance_to_vbs   par10
# 0                      0.0   160.0
# 1                      1.0     5.0
# 2                     45.0    46.0
# 3                      0.0   128.0
# 4                     32.0    39.0
# ...                    ...     ...
# 36619                 22.0    48.0
# 36620                 30.0   106.0
# 36621               1661.0  4063.0
# 36622                 20.0   859.0
# 36623                268.0   434.0
#
# [36624 rows x 15 columns]
#         Unnamed: 0  split  seed                              problem_instance  \
# 0                0      1    15         1-fullins-4-5.xml.watchless.minion.gz
# 1                1      1    15      1-insertions-6-4.xml.watchless.minion.gz
# 2                2      1    15      1-insertions-6-6.xml.watchless.minion.gz
# 3                3      1    15         2-fullins-3-5.xml.watchless.minion.gz
# 4                4      1    15      2-insertions-4-3.xml.watchless.minion.gz
# ...            ...    ...   ...                                           ...
# 339215      339215     10    15              series-90.xml.minion.conv.minion
# 339216      339216     10    15                 socialGolfer-8-4-8.xml.minion
# 339217      339217     10    15  tsp-20-68_ext.xml.minion.converted.minion.gz
# 339218      339218     10    15  tsp-20-75_ext.xml.minion.converted.minion.gz
# 339219      339219     10    15         will199GPIA-7.xml.watchless.minion.gz
#
#         lambda  quadratic_transform max_inverse_transform  \
# 0          0.0                 True                  none
# 1          0.0                 True                  none
# 2          0.0                 True                  none
# 3          0.0                 True                  none
# 4          0.0                 True                  none
# ...        ...                  ...                   ...
# 339215     1.0                False                  none
# 339216     1.0                False                  none
# 339217     1.0                False                  none
# 339218     1.0                False                  none
# 339219     1.0                False                  none
#
#         scale_to_unit_interval  tau_corr  tau_p      ndcg           mse  \
# 0                         True       1.0    1.0  1.000000  3.163369e+07
# 1                         True       NaN    NaN       NaN  2.486071e+09
# 2                         True       NaN    NaN       NaN  2.102163e+09
# 3                         True       1.0    1.0  1.000000  8.765241e+06
# 4                         True       1.0    1.0  1.000000  2.883872e+07
# ...                        ...       ...    ...       ...           ...
# 339215                   False       NaN    NaN       NaN  2.499999e+09
# 339216                   False       NaN    NaN       NaN  2.499975e+09
# 339217                   False      -1.0    1.0  0.999998  5.216726e+00
# 339218                   False      -1.0    1.0  0.942324  6.779054e+05
# 339219                   False      -1.0    1.0  0.999999  1.337183e+00
#
#                  mae  abs_distance_to_vbs         par10
# 0        4540.897976             0.000000      0.171973
# 1       49854.600919             0.000000  50000.000000
# 2       45724.270872             0.000000  50000.000000
# 3        2425.506797             0.000000      0.162975
# 4        5369.807321             0.000000      0.099985
# ...              ...                  ...           ...
# 339215  49999.994253             0.000000  50000.000000
# 339216  49999.724052             0.000000  50000.000000
# 339217      2.197756             0.043994      0.682896
# 339218    583.267410          1159.104556   1162.869984
# 339219      1.081628             0.029994      0.306952
#
# [339220 rows x 15 columns]
#         Unnamed: 0  split  seed                              problem_instance  \
# 0                0      1    15         1-fullins-4-5.xml.watchless.minion.gz
# 1                1      1    15      1-insertions-6-4.xml.watchless.minion.gz
# 2                2      1    15      1-insertions-6-6.xml.watchless.minion.gz
# 3                3      1    15         2-fullins-3-5.xml.watchless.minion.gz
# 4                4      1    15      2-insertions-4-3.xml.watchless.minion.gz
# ...            ...    ...   ...                                           ...
# 339215      339215     10    15              series-90.xml.minion.conv.minion
# 339216      339216     10    15                 socialGolfer-8-4-8.xml.minion
# 339217      339217     10    15  tsp-20-68_ext.xml.minion.converted.minion.gz
# 339218      339218     10    15  tsp-20-75_ext.xml.minion.converted.minion.gz
# 339219      339219     10    15         will199GPIA-7.xml.watchless.minion.gz
#
#         lambda  quadratic_transform max_inverse_transform  \
# 0          0.0                 True                  none
# 1          0.0                 True                  none
# 2          0.0                 True                  none
# 3          0.0                 True                  none
# 4          0.0                 True                  none
# ...        ...                  ...                   ...
# 339215     1.0                False                  none
# 339216     1.0                False                  none
# 339217     1.0                False                  none
# 339218     1.0                False                  none
# 339219     1.0                False                  none
#
#         scale_to_unit_interval  tau_corr  tau_p      ndcg           mse  \
# 0                         True       1.0    1.0  1.000000  3.163369e+07
# 1                         True       NaN    NaN       NaN  2.486071e+09
# 2                         True       NaN    NaN       NaN  2.102163e+09
# 3                         True       1.0    1.0  1.000000  8.765241e+06
# 4                         True       1.0    1.0  1.000000  2.883872e+07
# ...                        ...       ...    ...       ...           ...
# 339215                   False       NaN    NaN       NaN  2.499999e+09
# 339216                   False       NaN    NaN       NaN  2.499975e+09
# 339217                   False      -1.0    1.0  0.999998  5.216726e+00
# 339218                   False      -1.0    1.0  0.942324  6.779054e+05
# 339219                   False      -1.0    1.0  0.999999  1.337183e+00
#
#                  mae  abs_distance_to_vbs         par10
# 0        4540.897976             0.000000      0.171973
# 1       49854.600919             0.000000  50000.000000
# 2       45724.270872             0.000000  50000.000000
# 3        2425.506797             0.000000      0.162975
# 4        5369.807321             0.000000      0.099985
# ...              ...                  ...           ...
# 339215  49999.994253             0.000000  50000.000000
# 339216  49999.724052             0.000000  50000.000000
# 339217      2.197756             0.043994      0.682896
# 339218    583.267410          1159.104556   1162.869984
# 339219      1.081628             0.029994      0.306952
#
# [339220 rows x 15 columns]
#        Unnamed: 0  split  seed  \
# 0               0      1    15
# 1               1      1    15
# 2               2      1    15
# 3               3      1    15
# 4               4      1    15
# ...           ...    ...   ...
# 19368       19368     10    15
# 19369       19369     10    15
# 19370       19370     10    15
# 19371       19371     10    15
# 19372       19372     10    15
#
#                                         problem_instance  lambda  \
# 0      ./SAT02/industrial/dellacherie/comb/comb1.shuf...    0.01
# 1      ./SAT02/industrial/nam/fpga-routing/k2fix_gr_r...    0.01
# 2      ./SAT03/industrial/schuppan/l2s/bc57-sensors-1...    0.01
# 3      ./SAT04/industrial/vangelder/cnf-color/abb313G...    0.01
# 4      ./SAT04/industrial/velev/vliw_unsat_2.0/9dlx_v...    0.01
# ...                                                  ...     ...
# 19368  ./SAT11/application/rintanen/SATPlanning/block...    1.00
# 19369  ./SAT11/application/rintanen/SATPlanning/block...    1.00
# 19370  ./SAT11/application/rintanen/SATPlanning/sokob...    1.00
# 19371  ./SAT11/application/rintanen/SATPlanning/trans...    1.00
# 19372  SAT-Race-2010-CNF/hardware-verification/velev/...    1.00
#
#        quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 0                     True             max_par10                    True
# 1                     True             max_par10                    True
# 2                     True             max_par10                    True
# 3                     True             max_par10                    True
# 4                     True             max_par10                    True
# ...                    ...                   ...                     ...
# 19368                False             max_par10                   False
# 19369                False             max_par10                   False
# 19370                False             max_par10                   False
# 19371                False             max_par10                   False
# 19372                False             max_par10                   False
#
#        tau_corr     tau_p      ndcg           mse           mae  \
# 0     -0.110112  0.536081  0.823749  1.580563e+09  34474.449900
# 1     -0.176471  0.329674  0.973728  3.390054e+09  56057.425550
# 2      0.320261  0.068497  0.986150  2.655523e+08  11633.417493
# 3      0.288526  0.095352  0.978473  5.237770e+09  63773.852612
# 4      0.538996  0.004217  0.836866  9.076981e+08  22354.554815
# ...         ...       ...       ...           ...           ...
# 19368  0.228758  0.200825  0.974253  2.381109e+09  48793.822802
# 19369  0.163399  0.368581  0.998623  2.493197e+09  49931.871089
# 19370  0.123208  0.528991  0.467513  5.052854e+08  10660.515129
# 19371 -0.047324  0.788413  0.816343  1.613876e+09  34136.578189
# 19372  0.530664  0.003895  0.936343  1.196015e+09  24477.253297
#
#        abs_distance_to_vbs       par10
# 0                 40.37310    113.1110
# 1                370.98310    410.8570
# 2                214.38600   1126.0900
# 3                153.30321    154.7080
# 4               1946.55000   3091.1400
# ...                    ...         ...
# 19368            104.31200    486.2710
# 19369             17.80030     37.4903
# 19370          48904.83000  50000.0000
# 19371            717.31100   1228.2000
# 19372            280.88900    604.5330
#
# [19373 rows x 15 columns]
#        Unnamed: 0  split  seed  \
# 0               0      1    15
# 1               1      1    15
# 2               2      1    15
# 3               3      1    15
# 4               4      1    15
# ...           ...    ...   ...
# 19368       19368     10    15
# 19369       19369     10    15
# 19370       19370     10    15
# 19371       19371     10    15
# 19372       19372     10    15
#
#                                         problem_instance  lambda  \
# 0      ./SAT02/industrial/dellacherie/comb/comb1.shuf...    0.01
# 1      ./SAT02/industrial/nam/fpga-routing/k2fix_gr_r...    0.01
# 2      ./SAT03/industrial/schuppan/l2s/bc57-sensors-1...    0.01
# 3      ./SAT04/industrial/vangelder/cnf-color/abb313G...    0.01
# 4      ./SAT04/industrial/velev/vliw_unsat_2.0/9dlx_v...    0.01
# ...                                                  ...     ...
# 19368  ./SAT11/application/rintanen/SATPlanning/block...    1.00
# 19369  ./SAT11/application/rintanen/SATPlanning/block...    1.00
# 19370  ./SAT11/application/rintanen/SATPlanning/sokob...    1.00
# 19371  ./SAT11/application/rintanen/SATPlanning/trans...    1.00
# 19372  SAT-Race-2010-CNF/hardware-verification/velev/...    1.00
#
#        quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 0                     True             max_par10                    True
# 1                     True             max_par10                    True
# 2                     True             max_par10                    True
# 3                     True             max_par10                    True
# 4                     True             max_par10                    True
# ...                    ...                   ...                     ...
# 19368                False             max_par10                   False
# 19369                False             max_par10                   False
# 19370                False             max_par10                   False
# 19371                False             max_par10                   False
# 19372                False             max_par10                   False
#
#        tau_corr     tau_p      ndcg           mse           mae  \
# 0     -0.110112  0.536081  0.823749  1.580563e+09  34474.449900
# 1     -0.176471  0.329674  0.973728  3.390054e+09  56057.425550
# 2      0.320261  0.068497  0.986150  2.655523e+08  11633.417493
# 3      0.288526  0.095352  0.978473  5.237770e+09  63773.852612
# 4      0.538996  0.004217  0.836866  9.076981e+08  22354.554815
# ...         ...       ...       ...           ...           ...
# 19368  0.228758  0.200825  0.974253  2.381109e+09  48793.822802
# 19369  0.163399  0.368581  0.998623  2.493197e+09  49931.871089
# 19370  0.123208  0.528991  0.467513  5.052854e+08  10660.515129
# 19371 -0.047324  0.788413  0.816343  1.613876e+09  34136.578189
# 19372  0.530664  0.003895  0.936343  1.196015e+09  24477.253297
#
#        abs_distance_to_vbs       par10
# 0                 40.37310    113.1110
# 1                370.98310    410.8570
# 2                214.38600   1126.0900
# 3                153.30321    154.7080
# 4               1946.55000   3091.1400
# ...                    ...         ...
# 19368            104.31200    486.2710
# 19369             17.80030     37.4903
# 19370          48904.83000  50000.0000
# 19371            717.31100   1228.2000
# 19372            280.88900    604.5330
#
# [19373 rows x 15 columns]
#        Unnamed: 0  split  seed  \
# 0               0      1    15
# 1               1      1    15
# 2               2      1    15
# 3               3      1    15
# 4               4      1    15
# ...           ...    ...   ...
# 49723       49723     10    15
# 49724       49724     10    15
# 49725       49725     10    15
# 49726       49726     10    15
# 49727       49727     10    15
#
#                                         problem_instance  lambda  \
# 0      ./SAT03/handmade/anton/UNSAT/SGI_30_60_28_40_7...     0.0
# 1      ./SAT03/handmade/stanion/hwb/hwb-n32-02-S14785...     0.0
# 2      ./SAT05/crafted/jarvisalo05/mod2-rand3bip-sat/...     0.0
# 3      ./SAT05/crafted/jarvisalo05/mod2c-rand3bip-sat...     0.0
# 4      ./SAT05/crafted/sabharwal05/planning/logistics...     0.0
# ...                                                  ...     ...
# 49723      ./SAT11/crafted/mosoi/289/289-unsat-14x38.cnf     1.0
# 49724  ./SAT11/crafted/skvortsov/battleship/battleshi...     1.0
# 49725  ./SAT11/crafted/skvortsov/battleship/battleshi...     1.0
# 49726  ./SAT11/crafted/spence/sgen/sgen3-n130-s309409...     1.0
# 49727  ./SAT11/crafted/spence/sgen/sgen3-n260-s623210...     1.0
#
#        quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 0                     True                  none                    True
# 1                     True                  none                    True
# 2                     True                  none                    True
# 3                     True                  none                    True
# 4                     True                  none                    True
# ...                    ...                   ...                     ...
# 49723                False             max_par10                   False
# 49724                False             max_par10                   False
# 49725                False             max_par10                   False
# 49726                False             max_par10                   False
# 49727                False             max_par10                   False
#
#        tau_corr     tau_p      ndcg           mse           mae  \
# 0      0.104328  0.643429  0.356207  8.451010e+08  21090.251244
# 1           NaN       NaN       NaN  5.837298e+08  17550.495350
# 2     -0.046881  0.830182  0.766686  1.396414e+09  34731.419404
# 3      0.646165  0.001986  0.908346  1.314080e+08   5777.281178
# 4      0.172251  0.372467  0.987682  1.961951e+09  37073.542130
# ...         ...       ...       ...           ...           ...
# 49723       NaN       NaN       NaN  2.524872e+03     43.571773
# 49724  0.367188  0.058890  0.969188  1.963434e+09  39628.281897
# 49725       NaN       NaN       NaN  1.649358e+03     32.878475
# 49726       NaN       NaN       NaN  5.386918e+03     59.301754
# 49727  0.609449  0.005302  1.000000  4.956525e+08  10000.805854
#
#        abs_distance_to_vbs         par10
# 0             45953.000000  50000.000000
# 1                 0.000000  50000.000000
# 2                 0.000000      0.005998
# 3              1733.261000   1868.420000
# 4                 4.162369      4.681290
# ...                    ...           ...
# 49723             0.000000  50000.000000
# 49724             7.858800     32.129100
# 49725             0.000000  50000.000000
# 49726             0.000000  50000.000000
# 49727             0.000000     17.054400
#
# [49728 rows x 15 columns]
#        Unnamed: 0  split  seed  \
# 0               0      1    15
# 1               1      1    15
# 2               2      1    15
# 3               3      1    15
# 4               4      1    15
# ...           ...    ...   ...
# 49723       49723     10    15
# 49724       49724     10    15
# 49725       49725     10    15
# 49726       49726     10    15
# 49727       49727     10    15
#
#                                         problem_instance  lambda  \
# 0      ./SAT03/handmade/anton/UNSAT/SGI_30_60_28_40_7...     0.0
# 1      ./SAT03/handmade/stanion/hwb/hwb-n32-02-S14785...     0.0
# 2      ./SAT05/crafted/jarvisalo05/mod2-rand3bip-sat/...     0.0
# 3      ./SAT05/crafted/jarvisalo05/mod2c-rand3bip-sat...     0.0
# 4      ./SAT05/crafted/sabharwal05/planning/logistics...     0.0
# ...                                                  ...     ...
# 49723      ./SAT11/crafted/mosoi/289/289-unsat-14x38.cnf     1.0
# 49724  ./SAT11/crafted/skvortsov/battleship/battleshi...     1.0
# 49725  ./SAT11/crafted/skvortsov/battleship/battleshi...     1.0
# 49726  ./SAT11/crafted/spence/sgen/sgen3-n130-s309409...     1.0
# 49727  ./SAT11/crafted/spence/sgen/sgen3-n260-s623210...     1.0
#
#        quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 0                     True                  none                    True
# 1                     True                  none                    True
# 2                     True                  none                    True
# 3                     True                  none                    True
# 4                     True                  none                    True
# ...                    ...                   ...                     ...
# 49723                False             max_par10                   False
# 49724                False             max_par10                   False
# 49725                False             max_par10                   False
# 49726                False             max_par10                   False
# 49727                False             max_par10                   False
#
#        tau_corr     tau_p      ndcg           mse           mae  \
# 0      0.104328  0.643429  0.356207  8.451010e+08  21090.251244
# 1           NaN       NaN       NaN  5.837298e+08  17550.495350
# 2     -0.046881  0.830182  0.766686  1.396414e+09  34731.419404
# 3      0.646165  0.001986  0.908346  1.314080e+08   5777.281178
# 4      0.172251  0.372467  0.987682  1.961951e+09  37073.542130
# ...         ...       ...       ...           ...           ...
# 49723       NaN       NaN       NaN  2.524872e+03     43.571773
# 49724  0.367188  0.058890  0.969188  1.963434e+09  39628.281897
# 49725       NaN       NaN       NaN  1.649358e+03     32.878475
# 49726       NaN       NaN       NaN  5.386918e+03     59.301754
# 49727  0.609449  0.005302  1.000000  4.956525e+08  10000.805854
#
#        abs_distance_to_vbs         par10
# 0             45953.000000  50000.000000
# 1                 0.000000  50000.000000
# 2                 0.000000      0.005998
# 3              1733.261000   1868.420000
# 4                 4.162369      4.681290
# ...                    ...           ...
# 49723             0.000000  50000.000000
# 49724             7.858800     32.129100
# 49725             0.000000  50000.000000
# 49726             0.000000  50000.000000
# 49727             0.000000     17.054400
#
# [49728 rows x 15 columns]
