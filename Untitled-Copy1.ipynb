# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from Corras.Scenario.aslib_ranking_scenario import ASRankingScenario
from itertools import product

# measures
from scipy.stats import kendalltau, describe
from sklearn.metrics import mean_absolute_error, mean_squared_error
from Corras.Evaluation.evaluation import ndcg_at_k, compute_relevance_scores_unit_interval

# plotting
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
scenario_path = "./aslib_data-aslib-v4.0/"
evaluations_path = "./evaluations/"

figures_path = "./figures/progression-plots/"
scenario_names = ["SAT11-RAND", "MIP-2016",
                  "CSP-2010", "SAT11-INDU", "SAT11-HAND"]
use_quadratic_transform_values = [True]
use_max_inverse_transform_values = ["max_cutoff", "max_par10"]
# scale_target_to_unit_interval_values = [True, False]
scale_target_to_unit_interval_values = [True]
seed = 15

params = [scenario_names, use_quadratic_transform_values,
          use_max_inverse_transform_values, scale_target_to_unit_interval_values]

param_product = list(product(*params))

# %%
def max_formatter(x):
#     if x is None:
#         return "blubb"
    if float(x) >= 0.8:
        return "$\\boldsymbol{" + str(x) + "}$"
    else: 
        return str(x)

# %%
comparison_data = []
for scenario_name in scenario_names:
    try:
        df_baseline_lr = pd.read_csv(
            evaluations_path + "baseline-evaluation-linear_regression" + scenario_name + ".csv")
        df_baseline_rf = pd.read_csv(
            evaluations_path + "baseline-evaluation-random_forest" + scenario_name + ".csv")
        df_corras_all =  pd.read_csv(
            evaluations_path + "corras-pl-log-linear-" + scenario_name + ".csv")
        df_corras_linear = df_corras_all.loc[(df_corras_all["seed"] == seed) & (
            df_corras_all["quadratic_transform"] == False) & (df_corras_all["scale_to_unit_interval"] == True) & (df_corras_all["max_inverse_transform"] == "max_cutoff") & (df_corras_all["lambda"] == 0.5)]
        df_corras_quadratic = df_corras_all.loc[(df_corras_all["seed"] == seed) & (
            df_corras_all["quadratic_transform"] == True) & (df_corras_all["scale_to_unit_interval"] == True) & (df_corras_all["max_inverse_transform"] == "max_cutoff") & (df_corras_all["lambda"] == 0.5)]

    except:
        print("Scenario " + scenario_name +
              " not found in corras evaluation data!")
    comparison_data.append([scenario_name, df_baseline_rf["run_status"].value_counts(normalize=True)["ok"], df_baseline_lr["run_status"].value_counts(normalize=True)["ok"], df_corras_linear["run_status"].value_counts(normalize=True)["ok"], df_corras_quadratic["run_status"].value_counts(normalize=True)["ok"]])
comparison_frame = pd.DataFrame(data=comparison_data, columns=["Scenario", "Random Forest", "Linear Regression", "Corras Linear", "Corras Quadratic"])

print()

# %%
df_baseline_rf.head()
# Out:
#    Unnamed: 0                                   problem_instance  tau_corr  \
# 0           0  ./SAT02/handmade/chu-min-li/urquhart/urquhart3...  0.596154
# 1           1  ./SAT02/handmade/pehoushek/plainoldcnf/5cnf_35...  0.367188
# 2           2  ./SAT02/handmade/pehoushek/plainoldcnf/5cnf_39...  0.440196
# 3           3  ./SAT02/handmade/pehoushek/plainoldcnf/5cnf_39...  0.715834
# 4           4  ./SAT02/handmade/pehoushek/plainoldcnf/5cnf_43...  0.617914
#
#       tau_p      ndcg           mse           mae  abs_distance_to_vbs  \
# 0  0.002100  0.993098  1.315123e+08   9143.475041             0.085987
# 1  0.059099  0.999999  8.883693e+07   6653.082419             0.002999
# 2  0.022655  0.998835  9.545797e+07   7126.787619            41.963610
# 3  0.000838  0.998160  2.240570e+08   9309.888329             0.000000
# 4  0.001625  0.983404  4.455821e+08  17263.004389             0.000000
#
#        par10  par10_with_feature_cost run_status
# 0   0.087986                 4.597986         ok
# 1   0.006998                 3.136998         ok
# 2  43.333400                51.373400         ok
# 3   0.033994                14.903994         ok
# 4   0.019996                12.319996         ok

# %%
comparison_data = []
for scenario_name in scenario_names:
    try:
        df_baseline_lr = pd.read_csv(
            evaluations_path + "baseline-evaluation-linear-regression" + scenario_name + ".csv")
        df_baseline_rf = pd.read_csv(
            evaluations_path + "baseline-evaluation-random_forest" + scenario_name + ".csv")
        df_corras_all =  pd.read_csv(
            evaluations_path + "corras-pl-log-linear-" + scenario_name + ".csv")
        df_corras_linear = df_corras_all.loc[(df_corras_all["seed"] == seed) & (
            df_corras_all["quadratic_transform"] == False) & (df_corras_all["scale_to_unit_interval"] == True) & (df_corras_all["max_inverse_transform"] == "max_cutoff") & (df_corras_all["lambda"] == 0.5)]
        df_corras_quadratic = df_corras_all.loc[(df_corras_all["seed"] == seed) & (
            df_corras_all["quadratic_transform"] == True) & (df_corras_all["scale_to_unit_interval"] == True) & (df_corras_all["max_inverse_transform"] == "max_cutoff") & (df_corras_all["lambda"] == 0.5)]
        df_corras_nnh_all = pd.read_csv(
            evaluations_path + "corras-hinge-nn-" + scenario_name + "-short.csv")
        df_corras_nnh = df_corras_nnh_all.loc[(df_corras_nnh_all["seed"] == seed) & (df_corras_nnh_all["learning_rate"] == 0.01) & (df_corras_nnh_all["epsilon"] == 0.1) & (df_corras_nnh_all["seed"] == seed)]
    except:
        print("Scenario " + scenario_name +
              " not found in corras evaluation data!")
        continue
    comparison_data.append([scenario_name, df_baseline_rf["par10"].mean(), df_baseline_lr["par10"].mean(), df_corras_linear["par10"].mean(), df_corras_quadratic["par10"].mean(), df_corras_nnh["par10"].mean()])
comparison_frame = pd.DataFrame(data=comparison_data, columns=["Scenario", "Random Forest", "Linear Regression", "pl linear", "pl quadratic", "hinge nn"])
comparison_frame
# Out:
#      Scenario  Random Forest  Linear Regression     pl linear  pl quadratic  \
# 0  SAT11-RAND    9899.422950       11602.316247  11912.711824  11551.718761
# 1    MIP-2016    3949.087156       10582.536697   2690.701835   4613.733945
# 2    CSP-2010    6495.904047        6611.510080   6583.513174   6486.555555
# 3  SAT11-INDU   12491.122649       13332.173437  15375.062595  15469.799074
# 4  SAT11-HAND   19416.264628       19806.305930  19433.751787  19265.072657
#
#    hinge nn
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
print(comparison_frame.to_latex(na_rep="-", index=False, bold_rows=True, float_format="%.3f", formatters={"tau_corr" : max_formatter}, escape=False))
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
#    Scenario &  Random Forest &  Linear Regression &  pl linear &  pl quadratic &  hinge nn \\
# \midrule
#  SAT11-RAND &       9899.423 &          11602.316 &  11912.712 &     11551.719 &         - \\
#    MIP-2016 &       3949.087 &          10582.537 &   2690.702 &      4613.734 &         - \\
#    CSP-2010 &       6495.904 &           6611.510 &   6583.513 &      6486.556 &         - \\
#  SAT11-INDU &      12491.123 &          13332.173 &  15375.063 &     15469.799 &         - \\
#  SAT11-HAND &      19416.265 &          19806.306 &  19433.752 &     19265.073 &         - \\
# \bottomrule
# \end{tabular}

# %%
for scenario_name, use_quadratic_transform, use_max_inverse_transform, scale_target_to_unit_interval in param_product:
    df_baseline_lr = None
    df_baseline_rf = None
    try:
        df_baseline_lr = pd.read_csv(
            evaluations_path + "baseline-evaluation-linear-regression" + scenario_name + ".csv")
        df_baseline_rf = pd.read_csv(
            evaluations_path + "baseline-evaluation-random_forest" + scenario_name + ".csv")
    except:
        print("Scenario " + scenario_name +
              " not found in corras evaluation data!")

    params_string = "-".join([scenario_name,
                              str(use_quadratic_transform), str(use_max_inverse_transform), str(scale_target_to_unit_interval)])


        # continue
    try:
        # df_corras = pd.read_csv(evaluations_path + "corras-linhinge-evaluation-" + scenario_name + ".csv")
        corras = pd.read_csv(
            evaluations_path + "corras-pl-log-linear-" + scenario_name + ".csv")
    except:
        print("Scenario " + scenario_name +
              " not found in corras evaluation data!")
        continue
    current_frame = corras.loc[(corras["seed"] == seed) & (
    corras["quadratic_transform"] == use_quadratic_transform) & (corras["scale_to_unit_interval"] == scale_target_to_unit_interval) & (corras["max_inverse_transform"] == "max_cutoff")]

#     print(current_frame[:])
    print(current_frame.iloc[:10,8:12].to_latex(na_rep="-", index=False, bold_rows=True, float_format="%.2f", formatters={"tau_corr" : max_formatter}, escape=False))
    for measure in current_frame.columns[8:]:
        plt.clf()
        # bp = sns.boxplot(x="lambda", y=measure, hue="epsilon", data=df_corras)
        # bp = sns.boxplot(x="lambda", y=measure, data=df_corras)
        # if df_baseline is not None:
        #     bp.axes.axhline(df_baseline[measure].mean(), c="g", ls="--", label="rf-baseline-mean")
        # plt.title(scenario_name)
        # plt.legend()
        # plt.savefig(figures_path+scenario_name+"-" + measure +"-boxplot.pdf")

    for measure in current_frame.columns[8:]:
        plt.clf()
        # bp = sns.lineplot(x="lambda", y=measure, hue="epsilon", data=df_corras, palette=sns.color_palette("Set1", len(pd.unique(df_corras["epsilon"]))))
        # g = sns.FacetGrid(df_corras, col="max_inverse_transform")
        # g.map(sns.lineplot, "lambda", measure)
        lp = sns.lineplot(x="lambda", y=measure, hue="max_inverse_transform", data=current_frame)
        if df_baseline_rf is not None:
            lp.axes.axhline(df_baseline_rf[measure].mean(
            ), c="g", ls="--", label="rf-baseline-mean")
        if df_baseline_lr is not None:    
            lp.axes.axhline(df_baseline_lr[measure].mean(
            ), c="m", ls="--", label="lr-baseline-mean")
        plt.title(scenario_name)
        plt.legend()
        plt.savefig(figures_path + scenario_name + "-" + params_string.replace(".","_") + "-" + measure + "-lineplot-mi.pdf")
        plt.show()
# Out:
# \begin{tabular}{rrrr}
# \toprule
#                          tau_corr &  tau_p &  ndcg &           mse \\
# \midrule
#                0.4789207443461594 &   0.07 &  0.99 &  443653832.71 \\
# $\boldsymbol{0.9296696802013682}$ &   0.00 &  1.00 &  447396884.76 \\
#                0.5477225575051661 &   0.05 &  0.95 &  970389432.46 \\
#                0.7833494518006403 &   0.00 &  0.99 &  650685456.61 \\
#                0.7042952122737639 &   0.01 &  1.00 &  453597387.51 \\
#                0.7042952122737639 &   0.01 &  0.98 &  448560471.10 \\
#                  0.79115480528524 &   0.00 &  0.98 &  898345976.01 \\
#                0.5594309277855157 &   0.06 &  0.98 & 1699962752.61 \\
#                0.7844645405527362 &   0.01 &  0.98 & 1114589407.47 \\
#                0.4714045207910316 &   0.12 &  1.00 & 1813638742.56 \\
# \bottomrule
# \end{tabular}
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-8-901dfdee8f3d> in <module>
#      44         # g = sns.FacetGrid(df_corras, col="max_inverse_transform")
#      45         # g.map(sns.lineplot, "lambda", measure)
# ---> 46         lp = sns.lineplot(x="lambda", y=measure, hue="max_inverse_transform", data=current_frame)
#      47         if df_baseline_rf is not None:
#      48             lp.axes.axhline(df_baseline_rf[measure].mean(
#
# ~/.local/lib/python3.6/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1082         ax = plt.gca()
#    1083
# -> 1084     p.plot(ax, kwargs)
#    1085
#    1086     return ax
#
# ~/.local/lib/python3.6/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     773                     err = "estimator must be None when specifying units"
#     774                     raise ValueError(err)
# --> 775                 x, y, y_ci = self.aggregate(y, x, units)
#     776             else:
#     777                 y_ci = None
#
# ~/.local/lib/python3.6/site-packages/seaborn/relational.py in aggregate(self, vals, grouper, units)
#     703         # Group and get the aggregation estimate
#     704         grouped = vals.groupby(grouper, sort=self.sort)
# --> 705         est = grouped.agg(func)
#     706
#     707         # Exit early if we don't want a confidence interval
#
# ~/.local/lib/python3.6/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     843
#     844         if isinstance(func_or_funcs, str):
# --> 845             return getattr(self, func_or_funcs)(*args, **kwargs)
#     846
#     847         if isinstance(func_or_funcs, abc.Iterable):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1203         try:
#    1204             return self._cython_agg_general(
# -> 1205                 "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1206             )
#    1207         except GroupByError:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     886
#     887         if len(output) == 0:
# --> 888             raise DataError("No numeric types to aggregate")
#     889
#     890         return self._wrap_aggregated_output(output, names)
#
# DataError: No numeric types to aggregate

# %%
corras.head()
# Out:
#    Unnamed: 0  split  seed                                   problem_instance  \
# 0           0      1    15  ./SAT03/handmade/anton/UNSAT/SGI_30_60_28_40_7...
# 1           1      1    15  ./SAT03/handmade/stanion/hwb/hwb-n32-02-S14785...
# 2           2      1    15  ./SAT05/crafted/jarvisalo05/mod2-rand3bip-sat/...
# 3           3      1    15  ./SAT05/crafted/jarvisalo05/mod2c-rand3bip-sat...
# 4           4      1    15  ./SAT05/crafted/sabharwal05/planning/logistics...
#
#    lambda  quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 0     0.0                 True                  none                    True
# 1     0.0                 True                  none                    True
# 2     0.0                 True                  none                    True
# 3     0.0                 True                  none                    True
# 4     0.0                 True                  none                    True
#
#    tau_corr     tau_p      ndcg           mse           mae  \
# 0  0.104328  0.643429  0.356207  8.451010e+08  21090.251244
# 1       NaN       NaN       NaN  5.837298e+08  17550.495350
# 2 -0.046881  0.830182  0.766686  1.396414e+09  34731.419404
# 3  0.646165  0.001986  0.908346  1.314080e+08   5777.281178
# 4  0.172251  0.372467  0.987682  1.961951e+09  37073.542130
#
#    abs_distance_to_vbs         par10
# 0         45953.000000  50000.000000
# 1             0.000000  50000.000000
# 2             0.000000      0.005998
# 3          1733.261000   1868.420000
# 4             4.162369      4.681290
