# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from Corras.Scenario.aslib_ranking_scenario import ASRankingScenario
from itertools import product

# measures
from scipy.stats import kendalltau, describe
from sklearn.metrics import mean_absolute_error, mean_squared_error
from Corras.Evaluation.evaluation import ndcg_at_k, compute_relevance_scores_unit_interval

# plotting
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
scenario_path = "./aslib_data-aslib-v4.0/"
evaluations_path = "./evaluations/"

figures_path = "./figures/progression-plots/"
scenario_names = ["SAT11-RAND", "MIP-2016",
                  "CSP-2010", "SAT11-INDU", "SAT11-HAND"]
use_quadratic_transform_values = [False]
use_max_inverse_transform_values = ["max_cutoff"]
# scale_target_to_unit_interval_values = [True, False]
scale_target_to_unit_interval_values = [True]
seed = 15

params = [scenario_names, use_quadratic_transform_values,
          use_max_inverse_transform_values, scale_target_to_unit_interval_values]

param_product = list(product(*params))

# %%
for scenario_name, use_quadratic_transform, use_max_inverse_transform, scale_target_to_unit_interval in param_product:
    df_baseline = None
    params_string = "-".join([scenario_name,
                              str(use_quadratic_transform), str(use_max_inverse_transform), str(scale_target_to_unit_interval)])
    try:
        df_baseline = pd.read_csv(
            evaluations_path + "baseline-evaluation-" + scenario_name + ".csv")
    except:
        print("Scenario " + scenario_name +
              " not found in corras evaluation data!")

        # continue
    try:
        # df_corras = pd.read_csv(evaluations_path + "corras-linhinge-evaluation-" + scenario_name + ".csv")
        corras = pd.read_csv(
            evaluations_path + "corras-hinge-linear-" + scenario_name + ".csv")
    except:
        print("Scenario " + scenario_name +
              " not found in corras evaluation data!")
        continue
    current_frame = corras.loc[(corras["seed"] == seed) & (
    corras["max_inverse_transform"] == use_max_inverse_transform) & (
    corras["quadratic_transform"] == use_quadratic_transform) & (corras["scale_to_unit_interval"] == scale_target_to_unit_interval)]

    print(current_frame[:])
    for measure in current_frame.columns[9:]:
        plt.clf()
        # bp = sns.boxplot(x="lambda", y=measure, hue="epsilon", data=df_corras)
        # bp = sns.boxplot(x="lambda", y=measure, data=df_corras)
        # if df_baseline is not None:
        #     bp.axes.axhline(df_baseline[measure].mean(), c="g", ls="--", label="rf-baseline-mean")
        # plt.title(scenario_name)
        # plt.legend()
        # plt.savefig(figures_path+scenario_name+"-" + measure +"-boxplot.pdf")

    for measure in current_frame.columns[9:]:
        plt.clf()
        # bp = sns.lineplot(x="lambda", y=measure, hue="epsilon", data=df_corras, palette=sns.color_palette("Set1", len(pd.unique(df_corras["epsilon"]))))
        # g = sns.FacetGrid(df_corras, col="max_inverse_transform")
        # g.map(sns.lineplot, "lambda", measure)
        lp = sns.lineplot(x="lambda", y=measure, hue="epsilon", data=current_frame, ci=None, palette=sns.color_palette("Set1", len(pd.unique(current_frame["epsilon"]))))
        if df_baseline is not None:
            lp.axes.axhline(df_baseline[measure].mean(
            ), c="g", ls="--", label="rf-baseline-mean")
        plt.title(scenario_name)
        plt.legend()
        plt.savefig(figures_path + scenario_name + "-linear-hinge-" + params_string.replace(".","_") + "-" + measure + "-lineplot-eps.pdf")
        plt.show()
# Out:
#         Unnamed: 0  split  seed  \
# 480            480      1    15
# 481            481      1    15
# 482            482      1    15
# 483            483      1    15
# 484            484      1    15
# ...            ...    ...   ...
# 206515      206515     10    15
# 206516      206516     10    15
# 206517      206517     10    15
# 206518      206518     10    15
# 206519      206519     10    15
#
#                                          problem_instance  lambda  epsilon  \
# 480     SAT11/random/large/unif-k3-r4.2-v10000-c42000-...     0.0      0.0
# 481     SAT11/random/large/unif-k3-r4.2-v20000-c84000-...     0.0      0.0
# 482     SAT11/random/large/unif-k3-r4.2-v20000-c84000-...     0.0      0.0
# 483     SAT11/random/large/unif-k3-r4.2-v20000-c84000-...     0.0      0.0
# 484     SAT11/random/large/unif-k3-r4.2-v2500-c10500-S...     0.0      0.0
# ...                                                   ...     ...      ...
# 206515  SAT11/random/medium/unif-k7-r89-v70-c6230-S133...     0.9      0.3
# 206516  SAT11/random/medium/unif-k7-r89-v70-c6230-S204...     0.9      0.3
# 206517  SAT11/random/medium/unif-k7-r89-v70-c6230-S214...     0.9      0.3
# 206518  SAT11/random/medium/unif-k7-r89-v70-c6230-S250...     0.9      0.3
# 206519  SAT11/random/medium/unif-k7-r89-v90-c8010-S189...     0.9      0.3
#
#         quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 480                   False            max_cutoff                    True
# 481                   False            max_cutoff                    True
# 482                   False            max_cutoff                    True
# 483                   False            max_cutoff                    True
# 484                   False            max_cutoff                    True
# ...                     ...                   ...                     ...
# 206515                False            max_cutoff                    True
# 206516                False            max_cutoff                    True
# 206517                False            max_cutoff                    True
# 206518                False            max_cutoff                    True
# 206519                False            max_cutoff                    True
#
#         tau_corr     tau_p      ndcg           mse           mae  \
# 480          NaN       NaN  0.966271  4.689303e+08  13712.491835
# 481          NaN       NaN  0.949316  4.687337e+08  13534.210758
# 482          NaN       NaN  0.784682  9.181486e+08  22093.362106
# 483          NaN       NaN  0.912703  6.921039e+08  17882.931884
# 484          NaN       NaN  0.971212  4.685789e+08  13850.968136
# ...          ...       ...       ...           ...           ...
# 206515  0.388889  0.180181  0.999682  1.452703e+06   1085.660322
# 206516  0.333333  0.259518  0.997011  1.761521e+06   1253.528571
# 206517  0.500000  0.075176  0.999797  1.201648e+06    929.841063
# 206518 -0.645497  0.029809  0.376718  1.895260e+09  38878.345355
# 206519       NaN       NaN       NaN  2.378849e+09  48754.866954
#
#         abs_distance_to_vbs         par10
# 480                0.000000      5.944100
# 481                1.327800      9.951490
# 482                0.000000     85.363000
# 483                0.000000     21.060800
# 484                1.860720      3.773430
# ...                     ...           ...
# 206515             0.000000      0.029995
# 206516             3.349494      3.900410
# 206517             0.000000      2.047690
# 206518         45601.440000  50000.000000
# 206519             0.000000  50000.000000
#
# [17280 rows x 16 columns]
#         Unnamed: 0  split  seed problem_instance  lambda  epsilon  \
# 176            176      1    15           a1c1s1     0.0      0.0
# 177            177      1    15            air04     0.0      0.0
# 178            178      1    15  ash608gpia-3col     0.0      0.0
# 179            179      1    15          danoint     0.0      0.0
# 180            180      1    15           glass4     0.0      0.0
# ...            ...    ...   ...              ...     ...      ...
# 128020      128020      1    15         ns894244     0.9      0.3
# 128021      128021      1    15      opm2-z10-s2     0.9      0.3
# 128022      128022      1    15               pg     0.9      0.3
# 128023      128023      1    15         ran14x18     0.9      0.3
# 128024      128024      1    15        zib54-UUE     0.9      0.3
#
#         quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 176                   False            max_cutoff                    True
# 177                   False            max_cutoff                    True
# 178                   False            max_cutoff                    True
# 179                   False            max_cutoff                    True
# 180                   False            max_cutoff                    True
# ...                     ...                   ...                     ...
# 128020                False            max_cutoff                    True
# 128021                False            max_cutoff                    True
# 128022                False            max_cutoff                    True
# 128023                False            max_cutoff                    True
# 128024                False            max_cutoff                    True
#
#         tau_corr     tau_p      ndcg           mse           mae  \
# 176          NaN       NaN  0.705794  1.705400e+09  29690.001972
# 177          NaN       NaN  0.998799  5.286779e+07   7271.006386
# 178          NaN       NaN  0.989104  5.174926e+07   7192.250357
# 179          NaN       NaN  0.980202  4.541419e+07   6733.564428
# 180          NaN       NaN  0.710928  1.570292e+09  30832.365507
# ...          ...       ...       ...           ...           ...
# 128020  1.000000  0.016667  1.000000  2.219421e+05    456.090528
# 128021  0.836660  0.052204  1.000000  2.747993e+09  40998.668358
# 128022  0.447214  0.296270  0.999925  1.358490e+07   2859.323119
# 128023  0.400000  0.483333  0.989003  1.758415e+06   1013.846209
# 128024 -0.200000  0.816667  0.993127  1.647039e+08  11633.303722
#
#         abs_distance_to_vbs    par10
# 176                 71840.0  72000.0
# 177                    43.0     47.0
# 178                   382.0    383.0
# 179                   710.0    838.0
# 180                 71993.0  72000.0
# ...                     ...      ...
# 128020                  0.0    167.0
# 128021                  0.0   2031.0
# 128022                  0.0      3.0
# 128023                  0.0     85.0
# 128024                308.0    370.0
#
# [10662 rows x 16 columns]
# Scenario CSP-2010 not found in corras evaluation data!
#         Unnamed: 0  split  seed  \
# 240            240      1    15
# 241            241      1    15
# 242            242      1    15
# 243            243      1    15
# 244            244      1    15
# ...            ...    ...   ...
# 165138      165138     10    15
# 165139      165139     10    15
# 165140      165140     10    15
# 165141      165141     10    15
# 165142      165142     10    15
#
#                                          problem_instance  lambda  epsilon  \
# 240     ./SAT02/industrial/dellacherie/comb/comb1.shuf...     0.0      0.0
# 241     ./SAT02/industrial/nam/fpga-routing/k2fix_gr_r...     0.0      0.0
# 242     ./SAT03/industrial/schuppan/l2s/bc57-sensors-1...     0.0      0.0
# 243     ./SAT04/industrial/vangelder/cnf-color/abb313G...     0.0      0.0
# 244     ./SAT04/industrial/velev/vliw_unsat_2.0/9dlx_v...     0.0      0.0
# ...                                                   ...     ...      ...
# 165138  ./SAT11/application/rintanen/SATPlanning/block...     0.9      0.3
# 165139  ./SAT11/application/rintanen/SATPlanning/block...     0.9      0.3
# 165140  ./SAT11/application/rintanen/SATPlanning/sokob...     0.9      0.3
# 165141  ./SAT11/application/rintanen/SATPlanning/trans...     0.9      0.3
# 165142  SAT-Race-2010-CNF/hardware-verification/velev/...     0.9      0.3
#
#         quadratic_transform max_inverse_transform  scale_to_unit_interval  \
# 240                   False            max_cutoff                    True
# 241                   False            max_cutoff                    True
# 242                   False            max_cutoff                    True
# 243                   False            max_cutoff                    True
# 244                   False            max_cutoff                    True
# ...                     ...                   ...                     ...
# 165138                False            max_cutoff                    True
# 165139                False            max_cutoff                    True
# 165140                False            max_cutoff                    True
# 165141                False            max_cutoff                    True
# 165142                False            max_cutoff                    True
#
#         tau_corr     tau_p      ndcg           mse           mae  \
# 240          NaN       NaN  0.832640  6.844928e+08  17396.281544
# 241          NaN       NaN  0.953325  2.107945e+07   4550.074559
# 242          NaN       NaN  0.943209  1.390389e+07   3712.761682
# 243          NaN       NaN  0.861986  2.456389e+08   9159.550982
# 244          NaN       NaN  0.698988  1.246842e+09  28485.006108
# ...          ...       ...       ...           ...           ...
# 165138  0.254902  0.151923  0.965048  1.481262e+06   1006.969997
# 165139 -0.124183  0.500867  0.993746  2.262502e+06    970.696943
# 165140  0.123208  0.528991  0.497135  1.891008e+09  39113.625352
# 165141  0.087888  0.618199  0.753188  6.218862e+08  14247.525861
# 165142  0.097164  0.597135  0.786808  1.151525e+09  25348.996805
#
#         abs_distance_to_vbs       par10
# 240                 0.00000     72.7379
# 241              1747.58610   1787.4600
# 242              1351.34600   2263.0500
# 243             49998.59521  50000.0000
# 244              1288.09000   2432.6800
# ...                     ...         ...
# 165138            569.95500    951.9140
# 165139            230.11100    249.8010
# 165140          48904.83000  50000.0000
# 165141           3374.43100   3885.3200
# 165142           1326.61600   1650.2600
#
# [13800 rows x 16 columns]
# Scenario SAT11-HAND not found in corras evaluation data!

# %%
corras.head()
# Out:
#    Unnamed: 0  split  seed                                   problem_instance  \
# 0           0      1    15  SAT11/random/large/unif-k3-r4.2-v10000-c42000-...
# 1           1      1    15  SAT11/random/large/unif-k3-r4.2-v20000-c84000-...
# 2           2      1    15  SAT11/random/large/unif-k3-r4.2-v20000-c84000-...
# 3           3      1    15  SAT11/random/large/unif-k3-r4.2-v20000-c84000-...
# 4           4      1    15  SAT11/random/large/unif-k3-r4.2-v2500-c10500-S...
#
#    lambda  epsilon  quadratic_transform max_inverse_transform  \
# 0     0.0      0.0                 True                  none
# 1     0.0      0.0                 True                  none
# 2     0.0      0.0                 True                  none
# 3     0.0      0.0                 True                  none
# 4     0.0      0.0                 True                  none
#
#    scale_to_unit_interval  tau_corr     tau_p      ndcg           mse  \
# 0                    True  0.358569  0.243305  0.983010  5.573759e+08
# 1                    True       NaN       NaN  0.949316  5.360259e+08
# 2                    True       NaN       NaN  0.784682  1.020172e+09
# 3                    True  0.369274  0.237302  0.957807  7.981425e+08
# 4                    True       NaN       NaN  0.971212  5.761325e+08
#
#             mae  abs_distance_to_vbs     par10
# 0  11328.986797              2.39863   8.34273
# 1  11368.017070              1.32780   9.95149
# 2  22227.245251              0.00000  85.36300
# 3  16665.916851             48.55660  69.61740
# 4  12050.375897              1.86072   3.77343
